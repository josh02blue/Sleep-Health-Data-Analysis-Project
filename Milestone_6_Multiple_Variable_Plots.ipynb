# %% [markdown]
# ## Milestone 6

# %% [markdown]
# ### Create 2 plots by doing the following for each:
# 1.Choose two or more columns/variables, and create a plot visualizing their relationship.
#
# 2.Add a title and axes labels to the plot.
#
# 3.Add the plot to your project page and write several sentences telling the reader what they should notice or conclude from this plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sleep_data = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
sleep_data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ## Occupation vs Stress Level

# %%
sns.boxplot(x = "Occupation", y = "Stress Level", data = sleep_data)
plt.title("Stress Levels by Occupation")
plt.xticks(rotation=90);

# %% [markdown]
# ## Daily Steps vs Heart Rate

# %%
sns.relplot(x = "Daily Steps", y = "Heart Rate",hue = "Gender", data = sleep_data)
plt.title("Daily Steps vs Heart Rate by Gender")
# Out:
# Text(0.5, 1.0, 'Daily Steps vs Heart Rate by Gender')
