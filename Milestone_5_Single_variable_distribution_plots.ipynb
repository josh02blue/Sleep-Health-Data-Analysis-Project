# %% [markdown]
# ## Milestone 5

# %% [markdown]
# ### Choose 4 columns and do the following for each of these columns:
#
# 1.Plot the distribution of data in that column using an appropriate graph type.
#
# 2.Add a title and axes labels to the plot.
#
# 3.Add the plot to your project page and write several sentences telling the reader what they should notice about the plot (ex. shape of distribution, outliers, skew, anything surprising, etc)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sleep_data = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
sleep_data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ## Occupation Column

# %%
occupation_count = sleep_data["Occupation"].value_counts()
occupation_count.plot(kind = "bar")
plt.title("Distribution of Occupation")
plt.xlabel("Occupation")
plt.ylabel("# of people")
# Out:
# Text(0, 0.5, '# of people')

# %% [markdown]
# ## BMI Category Column

# %%
bmi_category_count = sleep_data["BMI Category"].value_counts()
bmi_category_count.plot(kind = "bar")
plt.title("Distribution of BMI")
plt.xlabel("BMI Categories")
plt.ylabel("# of people")
# Out:
# Text(0, 0.5, '# of people')

# %% [markdown]
# ## Age Column

# %%
sleep_data["Age"].hist()
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("# of people")
# Out:
# Text(0, 0.5, '# of people')

# %% [markdown]
# ## Stress Level Column

# %%
sleep_data["Stress Level"].hist(bins = 15)
plt.title("Distribution of Stress Level")
plt.xlabel("Stress Levels")
plt.ylabel("# of people")
# Out:
# Text(0, 0.5, '# of people')
